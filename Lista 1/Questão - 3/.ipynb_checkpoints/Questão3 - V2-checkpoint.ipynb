# %% [markdown]
# # Classificação de Padrões

# %% [markdown]
# 3 - Considere um problema de classificação de padrões constituído de oito padrões. A
# distribuição dos padrões forma um círculo centrado na origem de raio unitário e contido no
# círculo um losango também centrado na origem e com lados iguais a raiz de 2. Os dados das
# classe C1, C2, C3, C4 corresponde aos quatro setores do losango e as outras quatro classes
# correspondem aos setores delimitados pelo círculo e os lados do losango. Após gerar
# aleatoriamente dados que venham formar estas distribuições de dados, selecione um conjunto
# de treinamento e um conjunto de validação. Treine uma rede perceptron para classificar os
# padrões associados a cada uma das classes. Verifique o desempenho do classificador usando
# o conjunto de validação e calculando a matriz de confusão.

# %% [markdown]
# ### Importando Bibliotecas

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import random
from math import sqrt
import numpy as np
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %% [markdown]
# ### Gerando Dados Aleatórios Para Classificação

# %%
def Gerar_C1(instancias):
    points = []
    for i in range(instancias):
        x = random.uniform(0, 1)
        y = random.uniform(0, -x + 1)
        points.append([x, y, 0])
    return points

def Gerar_C2(instancias):
    points = []
    for i in range(instancias):
        x = random.uniform(-1, 0)
        y = random.uniform(0, x + 1)
        points.append([x, y, 1])
    return points

def Gerar_C3(instancias):
    points = []
    for i in range(instancias):
        x = random.uniform(-1, 0)
        y = random.uniform(-1-x, 0)
        points.append([x, y, 2])
    return points

def Gerar_C4(instancias):
    points = []
    for i in range(instancias):
        x = random.uniform(0, 1)
        y = random.uniform(-1+x, 0)
        points.append([x, y, 3])
    return points

def Gerar_C5(instancias):
    points = []
    for i in range(instancias):
        x = random.uniform(0, 1)
        y = random.uniform(1 - x, sqrt(1 - x**2))
        points.append([x, y, 4])
    return points

def Gerar_C6(instancias):
    points = []
    for i in range(instancias):
        x = random.uniform(-1, 0)
        y = random.uniform(x+1, sqrt(1 - x**2))
        points.append([x, y, 5])
    return points

def Gerar_C7(instancias):
    points = []
    for i in range(instancias):
        x = random.uniform(-1, 0)
        y = random.uniform(-sqrt(1 - x**2), -1-x)
        points.append([x, y, 6])
    return points

def Gerar_C8(instancias):
    points = []
    for i in range(instancias):
        x = random.uniform(0, 1)
        y = random.uniform(-sqrt(1 - x**2), -1+x)
        points.append([x, y, 7])
    return points

def generate(instancias):
    points = Gerar_C1(instancias) + Gerar_C2(instancias) + Gerar_C3(instancias) + Gerar_C4(instancias) + Gerar_C5(instancias) + Gerar_C6(instancias) + Gerar_C7(instancias) + Gerar_C8(instancias)
    return points

colors = cm.rainbow(np.linspace(0, 1, 8))

res = generate(200)
#print(res)

data_X = [[row[0], row[1]] for row in res]
data_X = np.array(data_X)
data_y = [row[2] for row in res]
data_y = np.array(data_y)

plt.scatter(data_X[:,0], data_X[:,1], color=colors[data_y])

#plt.legend()
_ = plt.ylim()

data_X, data_y = shuffle(data_X, data_y, random_state=0)

# %%
(train_X, test_X, train_y, test_y) = train_test_split(data_X, data_y)
X_size = (train_X.shape[0] + 8)/2
print(X_size)
# Out:
# 604.0

# %%
classificador = Sequential()

# %%
classificador.add(Dense(units = 12, activation = 'relu', input_dim = 2))
classificador.add(Dense(units = 12, activation = 'relu'))
classificador.add(Dense(units = 8, activation = 'softmax'))
classificador.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
H = classificador.fit(train_X, train_y, batch_size=32, epochs = 100)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1201 - accuracy: 0.9742
# Epoch 2/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1205 - accuracy: 0.9742
# Epoch 3/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1208 - accuracy: 0.9700
# Epoch 4/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1199 - accuracy: 0.9767
# Epoch 5/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1191 - accuracy: 0.9717
# Epoch 6/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1194 - accuracy: 0.9733
# Epoch 7/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1198 - accuracy: 0.9708
# Epoch 8/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1183 - accuracy: 0.9767
# Epoch 9/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1196 - accuracy: 0.9675
# Epoch 10/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1192 - accuracy: 0.9742
# Epoch 11/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1185 - accuracy: 0.9717
# Epoch 12/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1180 - accuracy: 0.9742
# Epoch 13/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1174 - accuracy: 0.9742
# Epoch 14/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1170 - accuracy: 0.9742
# Epoch 15/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1183 - accuracy: 0.9733
# Epoch 16/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1173 - accuracy: 0.9717
# Epoch 17/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1167 - accuracy: 0.9750
# Epoch 18/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1159 - accuracy: 0.9767
# Epoch 19/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1152 - accuracy: 0.9725
# Epoch 20/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1167 - accuracy: 0.9725
# Epoch 21/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1143 - accuracy: 0.9725
# Epoch 22/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1143 - accuracy: 0.9767: 0s - loss: 0.1098 - accuracy: 0.97
# Epoch 23/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1171 - accuracy: 0.9733
# Epoch 24/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1140 - accuracy: 0.9750
# Epoch 25/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1150 - accuracy: 0.9758
# Epoch 26/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1143 - accuracy: 0.9733
# Epoch 27/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1144 - accuracy: 0.9742
# Epoch 28/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1134 - accuracy: 0.9750
# Epoch 29/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1130 - accuracy: 0.9700
# Epoch 30/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1133 - accuracy: 0.9758
# Epoch 31/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1131 - accuracy: 0.9742
# Epoch 32/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1138 - accuracy: 0.9725
# Epoch 33/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1127 - accuracy: 0.9750
# Epoch 34/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1129 - accuracy: 0.9742
# Epoch 35/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1120 - accuracy: 0.9758
# Epoch 36/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1118 - accuracy: 0.9725
# Epoch 37/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1105 - accuracy: 0.9717
# Epoch 38/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1105 - accuracy: 0.9733
# Epoch 39/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1109 - accuracy: 0.9733
# Epoch 40/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1106 - accuracy: 0.9742
# Epoch 41/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1107 - accuracy: 0.9708
# Epoch 42/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1083 - accuracy: 0.9792
# Epoch 43/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1100 - accuracy: 0.9742
# Epoch 44/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1084 - accuracy: 0.9725
# Epoch 45/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1079 - accuracy: 0.9758
# Epoch 46/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1098 - accuracy: 0.9758
# Epoch 47/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1087 - accuracy: 0.9758
# Epoch 48/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1088 - accuracy: 0.9742
# Epoch 49/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1072 - accuracy: 0.9725
# Epoch 50/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1069 - accuracy: 0.9758
# Epoch 51/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1087 - accuracy: 0.9725
# Epoch 52/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1065 - accuracy: 0.9758
# Epoch 53/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1098 - accuracy: 0.97 - 0s 3ms/step - loss: 0.1094 - accuracy: 0.9717
# Epoch 54/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1078 - accuracy: 0.9725
# Epoch 55/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1057 - accuracy: 0.9725
# Epoch 56/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1074 - accuracy: 0.9708
# Epoch 57/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1051 - accuracy: 0.9725
# Epoch 58/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1046 - accuracy: 0.9758
# Epoch 59/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1065 - accuracy: 0.9775
# Epoch 60/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1054 - accuracy: 0.9767
# Epoch 61/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1054 - accuracy: 0.9725
# Epoch 62/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1051 - accuracy: 0.9742
# Epoch 63/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1039 - accuracy: 0.9750
# Epoch 64/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1064 - accuracy: 0.9742
# Epoch 65/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1029 - accuracy: 0.9758
# Epoch 66/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1046 - accuracy: 0.9742
# Epoch 67/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1040 - accuracy: 0.9800
# Epoch 68/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1033 - accuracy: 0.9758
# Epoch 69/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1026 - accuracy: 0.9708
# Epoch 70/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1023 - accuracy: 0.9775
# Epoch 71/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1039 - accuracy: 0.9733
# Epoch 72/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1014 - accuracy: 0.9767
# Epoch 73/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1016 - accuracy: 0.9767
# Epoch 74/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1000 - accuracy: 0.9783
# Epoch 75/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1009 - accuracy: 0.9750
# Epoch 76/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1002 - accuracy: 0.9725
# Epoch 77/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1010 - accuracy: 0.9758
# Epoch 78/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1006 - accuracy: 0.9750
# Epoch 79/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0991 - accuracy: 0.9742
# Epoch 80/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0997 - accuracy: 0.9758
# Epoch 81/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0996 - accuracy: 0.9742
# Epoch 82/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1007 - accuracy: 0.9783
# Epoch 83/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0998 - accuracy: 0.9758
# Epoch 84/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1015 - accuracy: 0.9717: 0s - loss: 0.0998 - accuracy: 0.97
# Epoch 85/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0973 - accuracy: 0.9792
# Epoch 86/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0994 - accuracy: 0.9767
# Epoch 87/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0979 - accuracy: 0.9750
# Epoch 88/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0998 - accuracy: 0.9750
# Epoch 89/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0975 - accuracy: 0.9742
# Epoch 90/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0992 - accuracy: 0.9758
# Epoch 91/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0971 - accuracy: 0.9767
# Epoch 92/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0977 - accuracy: 0.9783
# Epoch 93/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0961 - accuracy: 0.9800
# Epoch 94/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0972 - accuracy: 0.9758
# Epoch 95/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0962 - accuracy: 0.9775
# Epoch 96/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0964 - accuracy: 0.9775
# Epoch 97/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0960 - accuracy: 0.9725
# Epoch 98/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0992 - accuracy: 0.9708
# Epoch 99/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0986 - accuracy: 0.9767
# Epoch 100/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0965 - accuracy: 0.9750

# %%
previsoes = classificador.predict(test_X)
print(previsoes)
# Out:
# [[8.0108372e-03 1.6555576e-05 8.8359549e-16 ... 9.3695327e-08
#   0.0000000e+00 1.2526017e-25]
#  [9.1140819e-01 4.3710406e-05 5.9364270e-13 ... 9.0813811e-14
#   0.0000000e+00 9.8609647e-21]
#  [1.3025674e-03 5.7759680e-10 1.6394888e-18 ... 3.7549553e-21
#   0.0000000e+00 2.6118114e-19]
#  ...
#  [1.4967548e-05 1.5254107e-02 4.4177254e-13 ... 9.8473084e-01
#   0.0000000e+00 4.2308359e-30]
#  [1.2161065e-15 1.0007996e-12 1.1216637e-06 ... 0.0000000e+00
#   8.2165259e-20 1.2755513e-01]
#  [2.9185072e-05 1.5585547e-12 1.1023126e-21 ... 2.0213054e-24
#   0.0000000e+00 3.5809418e-20]]

# %%
precisao = accuracy_score(test_y, np.argmax(previsoes, axis = 1))
print(precisao*100,'%')


#matriz = confusion_matrix(classe_teste, previsoes)
# Out:
# 95.5 %

# %%
#accuracy_score(test_y, y_pred)
