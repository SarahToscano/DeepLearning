# %% [markdown]
# # Classificação de Padrões

# %% [markdown]
# 3 - Considere um problema de classificação de padrões constituído de oito padrões. A
# distribuição dos padrões forma um círculo centrado na origem de raio unitário e contido no
# círculo um losango também centrado na origem e com lados iguais a raiz de 2. Os dados das
# classe C1, C2, C3, C4 corresponde aos quatro setores do losango e as outras quatro classes
# correspondem aos setores delimitados pelo círculo e os lados do losango. Após gerar
# aleatoriamente dados que venham formar estas distribuições de dados, selecione um conjunto
# de treinamento e um conjunto de validação. Treine uma rede perceptron para classificar os
# padrões associados a cada uma das classes. Verifique o desempenho do classificador usando
# o conjunto de validação e calculando a matriz de confusão.

# %% [markdown]
# ### Importando Bibliotecas

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import random
from math import sqrt
import numpy as np
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score
from keras.models import Sequential
from keras.layers import Dense, Dropout
import seaborn as srn

# %% [markdown]
# ### Gerando Dados Aleatórios Para Classificação

# %%
def Gerar_C1(instancias):
    points = []
    for i in range(instancias):
        x = random.uniform(0, 1)
        y = random.uniform(0, -x + 1)
        points.append([x, y, 0])
    return points

def Gerar_C2(instancias):
    points = []
    for i in range(instancias):
        x = random.uniform(-1, 0)
        y = random.uniform(0, x + 1)
        points.append([x, y, 1])
    return points

def Gerar_C3(instancias):
    points = []
    for i in range(instancias):
        x = random.uniform(-1, 0)
        y = random.uniform(-1-x, 0)
        points.append([x, y, 2])
    return points

def Gerar_C4(instancias):
    points = []
    for i in range(instancias):
        x = random.uniform(0, 1)
        y = random.uniform(-1+x, 0)
        points.append([x, y, 3])
    return points

def Gerar_C5(instancias):
    points = []
    for i in range(instancias):
        x = random.uniform(0, 1)
        y = random.uniform(1 - x, sqrt(1 - x**2))
        points.append([x, y, 4])
    return points

def Gerar_C6(instancias):
    points = []
    for i in range(instancias):
        x = random.uniform(-1, 0)
        y = random.uniform(x+1, sqrt(1 - x**2))
        points.append([x, y, 5])
    return points

def Gerar_C7(instancias):
    points = []
    for i in range(instancias):
        x = random.uniform(-1, 0)
        y = random.uniform(-sqrt(1 - x**2), -1-x)
        points.append([x, y, 6])
    return points

def Gerar_C8(instancias):
    points = []
    for i in range(instancias):
        x = random.uniform(0, 1)
        y = random.uniform(-sqrt(1 - x**2), -1+x)
        points.append([x, y, 7])
    return points

def generate(instancias):
    points = Gerar_C1(instancias) + Gerar_C2(instancias) + Gerar_C3(instancias) + Gerar_C4(instancias) + Gerar_C5(instancias) + Gerar_C6(instancias) + Gerar_C7(instancias) + Gerar_C8(instancias)
    return points

colors = cm.rainbow(np.linspace(0, 1, 8))

res = generate(1000)
#print(res)

data_X = [[row[0], row[1]] for row in res]
data_X = np.array(data_X)
data_y = [row[2] for row in res]
data_y = np.array(data_y)

plt.scatter(data_X[:,0], data_X[:,1], color=colors[data_y])

#plt.legend()
_ = plt.ylim()

data_X, data_y = shuffle(data_X, data_y, random_state=0)

# %%
(train_X, test_X, train_y, test_y) = train_test_split(data_X, data_y)
X_size = (train_X.shape[0] + 8)/2
print(X_size)
# Out:
# 3004.0

# %%
classificador = Sequential()

# %%
classificador.add(Dense(units = 12, activation = 'relu', input_dim = 2))
classificador.add(Dense(units = 12, activation = 'relu'))
classificador.add(Dense(units = 8, activation = 'softmax'))
classificador.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
H = classificador.fit(train_X, train_y, batch_size=32, epochs = 100)
# Out:
# Epoch 1/100
# 188/188 [==============================] - 0s 937us/step - loss: 1.8978 - accuracy: 0.2813
# Epoch 2/100
# 188/188 [==============================] - 0s 1ms/step - loss: 1.4174 - accuracy: 0.4805
# Epoch 3/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.9846 - accuracy: 0.6327
# Epoch 4/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.7901 - accuracy: 0.6992
# Epoch 5/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.6945 - accuracy: 0.7403
# Epoch 6/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.6266 - accuracy: 0.7642
# Epoch 7/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.5687 - accuracy: 0.7963
# Epoch 8/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.5165 - accuracy: 0.8183
# Epoch 9/100
# 188/188 [==============================] - 0s 992us/step - loss: 0.4677 - accuracy: 0.8372
# Epoch 10/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4252 - accuracy: 0.8582
# Epoch 11/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.3924 - accuracy: 0.8765
# Epoch 12/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.3657 - accuracy: 0.8853
# Epoch 13/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.3435 - accuracy: 0.8933
# Epoch 14/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.3199 - accuracy: 0.9042
# Epoch 15/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.3017 - accuracy: 0.9133
# Epoch 16/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.2841 - accuracy: 0.9195
# Epoch 17/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.2693 - accuracy: 0.9243
# Epoch 18/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.2548 - accuracy: 0.9307
# Epoch 19/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.2441 - accuracy: 0.9348
# Epoch 20/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.2339 - accuracy: 0.9383
# Epoch 21/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.2250 - accuracy: 0.9412
# Epoch 22/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.2168 - accuracy: 0.9445
# Epoch 23/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.2105 - accuracy: 0.9435
# Epoch 24/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.2034 - accuracy: 0.9470
# Epoch 25/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1974 - accuracy: 0.9498
# Epoch 26/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1920 - accuracy: 0.9475
# Epoch 27/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1869 - accuracy: 0.9500
# Epoch 28/100
# 188/188 [==============================] - 0s 956us/step - loss: 0.1815 - accuracy: 0.9527
# Epoch 29/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1779 - accuracy: 0.9553
# Epoch 30/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1732 - accuracy: 0.9565
# Epoch 31/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1689 - accuracy: 0.9553
# Epoch 32/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1671 - accuracy: 0.9552
# Epoch 33/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1626 - accuracy: 0.9565
# Epoch 34/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1590 - accuracy: 0.9602
# Epoch 35/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1569 - accuracy: 0.9590
# Epoch 36/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1524 - accuracy: 0.9595
# Epoch 37/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1500 - accuracy: 0.9622
# Epoch 38/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1472 - accuracy: 0.9632
# Epoch 39/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1439 - accuracy: 0.9628
# Epoch 40/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1422 - accuracy: 0.9615
# Epoch 41/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1407 - accuracy: 0.9620
# Epoch 42/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1370 - accuracy: 0.9653
# Epoch 43/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1350 - accuracy: 0.9642
# Epoch 44/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1338 - accuracy: 0.9665
# Epoch 45/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1313 - accuracy: 0.9663
# Epoch 46/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.1297 - accuracy: 0.9648
# Epoch 47/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1285 - accuracy: 0.9633
# Epoch 48/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1264 - accuracy: 0.9683
# Epoch 49/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1237 - accuracy: 0.9685
# Epoch 50/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1233 - accuracy: 0.9667
# Epoch 51/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1208 - accuracy: 0.9712
# Epoch 52/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1200 - accuracy: 0.9690
# Epoch 53/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1180 - accuracy: 0.9700
# Epoch 54/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1169 - accuracy: 0.9710
# Epoch 55/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1166 - accuracy: 0.9695
# Epoch 56/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1139 - accuracy: 0.9707
# Epoch 57/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1119 - accuracy: 0.9713
# Epoch 58/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1125 - accuracy: 0.9702
# Epoch 59/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1100 - accuracy: 0.9722
# Epoch 60/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1101 - accuracy: 0.9712
# Epoch 61/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1079 - accuracy: 0.9710
# Epoch 62/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1056 - accuracy: 0.9748
# Epoch 63/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1059 - accuracy: 0.9713
# Epoch 64/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1046 - accuracy: 0.9703
# Epoch 65/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1026 - accuracy: 0.9733
# Epoch 66/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.1029 - accuracy: 0.9742
# Epoch 67/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1020 - accuracy: 0.9713
# Epoch 68/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.1003 - accuracy: 0.9735
# Epoch 69/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.0993 - accuracy: 0.9742
# Epoch 70/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0998 - accuracy: 0.9733
# Epoch 71/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.0981 - accuracy: 0.9757
# Epoch 72/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0978 - accuracy: 0.9727
# Epoch 73/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0978 - accuracy: 0.9737
# Epoch 74/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0954 - accuracy: 0.9768
# Epoch 75/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0947 - accuracy: 0.9745
# Epoch 76/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0944 - accuracy: 0.9765
# Epoch 77/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0929 - accuracy: 0.9770
# Epoch 78/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0924 - accuracy: 0.9755
# Epoch 79/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0923 - accuracy: 0.9760
# Epoch 80/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0916 - accuracy: 0.9750
# Epoch 81/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0902 - accuracy: 0.9785
# Epoch 82/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0891 - accuracy: 0.9760
# Epoch 83/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.0888 - accuracy: 0.9758
# Epoch 84/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0909 - accuracy: 0.9740
# Epoch 85/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.0881 - accuracy: 0.9745
# Epoch 86/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.0873 - accuracy: 0.9743
# Epoch 87/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0862 - accuracy: 0.9783
# Epoch 88/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0848 - accuracy: 0.9753
# Epoch 89/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0850 - accuracy: 0.9793
# Epoch 90/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0852 - accuracy: 0.9783
# Epoch 91/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0828 - accuracy: 0.9772
# Epoch 92/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0828 - accuracy: 0.9793
# Epoch 93/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0828 - accuracy: 0.9760
# Epoch 94/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0828 - accuracy: 0.9785
# Epoch 95/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0817 - accuracy: 0.9765
# Epoch 96/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.0814 - accuracy: 0.9790
# Epoch 97/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.0799 - accuracy: 0.9790
# Epoch 98/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0795 - accuracy: 0.9793
# Epoch 99/100
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0785 - accuracy: 0.9802
# Epoch 100/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.0798 - accuracy: 0.9775

# %%
previsoes = classificador.predict(test_X)
print(previsoes)
# Out:
# [[4.7029752e-10 5.3095311e-02 9.4685489e-01 ... 9.3302514e-13
#   1.7605674e-10 7.9373744e-19]
#  [5.2990741e-18 1.4984059e-07 9.3458742e-01 ... 8.2932541e-18
#   6.5412022e-02 1.5825235e-18]
#  [6.5390386e-06 9.9999321e-01 1.0027763e-07 ... 9.3907229e-11
#   1.0047729e-30 6.9273796e-25]
#  ...
#  [1.7179539e-04 1.5531407e-02 3.0676520e-25 ... 9.8429292e-01
#   0.0000000e+00 3.0050533e-30]
#  [9.8269470e-02 1.8499077e-21 9.9773638e-31 ... 0.0000000e+00
#   0.0000000e+00 3.1055056e-19]
#  [1.9297008e-11 1.5542584e-03 7.4489771e-15 ... 9.9844581e-01
#   6.2944502e-32 1.4260685e-28]]

# %%
precisao = accuracy_score(test_y, np.argmax(previsoes, axis = 1))
print(precisao*100,'%')
# Out:
# 97.5 %

# %%
matriz = confusion_matrix(test_y, np.argmax(previsoes, axis = 1))
print(matriz)
# Out:
# [[229   1   0   0   4   0   0   0]
#  [  0 248   0   0   0   3   0   0]
#  [  0   2 252   1   0   0   5   0]
#  [  9   0   1 244   0   0   0   7]
#  [  4   0   0   0 232   0   0   0]
#  [  0   0   0   0   0 261   0   0]
#  [  0   0   3   0   0   0 253   0]
#  [  0   0   0   7   0   0   3 231]]

# %%
colors = cm.rainbow(np.linspace(0, 1, 8))
plt.scatter(test_X[:,0], test_X[:,1], color=colors[np.argmax(previsoes, axis = 1)])
_ = plt.ylim()
